# %%
import numpy as np, pandas as pd 

df = pd.read_csv("predictive_maintenance_dataset.csv")

# %%
df
# Out:
#                 timestamp machine_id  vibration  acoustic  temperature  \
# 0     2024-07-01 08:00:00        M01      0.822     0.645        66.85
# 1     2024-07-01 08:01:00        M01      1.398     0.834        76.20
# 2     2024-07-01 08:02:00        M01      0.856     0.590        67.03
# 3     2024-07-01 08:03:00        M01      0.793     0.544        65.04
# 4     2024-07-01 08:04:00        M01      1.279     0.721        78.19
# ...                   ...        ...        ...       ...          ...
# 1795  2024-07-01 17:55:00        M03      1.163     0.889        78.43
# 1796  2024-07-01 17:56:00        M03      0.838     0.545        64.28
# 1797  2024-07-01 17:57:00        M03      0.786     0.593        65.44
# 1798  2024-07-01 17:58:00        M03      0.767     0.550        62.01
# 1799  2024-07-01 17:59:00        M03      0.934     0.643        64.18
#
#       current  IMF_1  IMF_2  IMF_3  label
# 0       13.04  0.196  0.033  0.000      0
# 1       15.08  0.345  0.132  0.001      1
# 2       12.30  0.187  0.017  0.002      0
# 3       11.69  0.196 -0.060  0.003      0
# 4       14.84  0.330 -0.115  0.004      1
# ...       ...    ...    ...    ...    ...
# 1795    14.41  0.261  0.041 -0.031      1
# 1796    12.08  0.146 -0.062 -0.030      0
# 1797    12.23  0.110  0.038 -0.029      0
# 1798    11.35  0.225  0.106 -0.028      0
# 1799    11.83  0.122  0.015 -0.028      0
#
# [1800 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# timestamp      0
# machine_id     0
# vibration      0
# acoustic       0
# temperature    0
# current        0
# IMF_1          0
# IMF_2          0
# IMF_3          0
# label          0
# dtype: int64

# %%
df.label.value_counts()
# Out:
# label
# 0    1598
# 1     202
# Name: count, dtype: int64

# %% [markdown]
# Total data samples: 1800
#
# Normal data samples: 1598
#
# Fault data samples: 202

# %%
import seaborn as sns

sns.pairplot(df, hue="label")
