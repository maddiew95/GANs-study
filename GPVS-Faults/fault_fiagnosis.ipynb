# %%
import numpy as np

scene1 = np.load("NPY_Files/scene1.npy")

# %%
scene1[:, 1:14]
# Out:
# array([[  2.16833496,  90.37475586, 147.36328125, ...,  50.34757669,
#         154.90102595,  50.00312735],
#        [  2.2913208 ,  90.56396484, 146.484375  , ...,  50.06763729,
#         154.96140425,  49.99529804],
#        [  2.22888184,  90.24047852, 148.2421875 , ...,  50.13437181,
#         155.3097055 ,  50.00426617],
#        ...,
#        [  2.32064819,  87.46337891, 148.53515625, ...,  50.07916763,
#         156.10857198,  50.0026428 ],
#        [  2.34902954,  87.0300293 , 147.94921875, ...,  49.94277388,
#         155.71552202,  49.99946699],
#        [  2.52688599,  86.40136719, 148.828125  , ...,  50.02217605,
#         155.96379572,  49.9993526 ]], shape=(11200, 13))
