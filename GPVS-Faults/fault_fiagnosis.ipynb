# %%
import pandas as pd, numpy as np
from util import *

# access each scene folder
scenarios = [f"CSV_Files/scene{i+1}/" for i in range(6)]

# %%
X_train_norm.shape, X_val_norm.shape, X_test_norm.shape
# Out:
# ((5726, 15), (1600, 15), (1600, 15))

# %%
log
# Out:
# {0: {'rows_before': 1000, 'rows_removed': 142, 'pct_removed': 14.2},
#  1: {'rows_before': 1000, 'rows_removed': 502, 'pct_removed': 50.2},
#  2: {'rows_before': 1000, 'rows_removed': 161, 'pct_removed': 16.1},
#  3: {'rows_before': 1000, 'rows_removed': 197, 'pct_removed': 19.7},
#  4: {'rows_before': 1000, 'rows_removed': 220, 'pct_removed': 22.0},
#  5: {'rows_before': 1000, 'rows_removed': 709, 'pct_removed': 70.9},
#  6: {'rows_before': 1000, 'rows_removed': 148, 'pct_removed': 14.8},
#  7: {'rows_before': 1000, 'rows_removed': 195, 'pct_removed': 19.5}}
